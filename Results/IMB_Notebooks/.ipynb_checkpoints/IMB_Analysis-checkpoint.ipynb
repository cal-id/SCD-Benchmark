# %% [markdown]
# # Analysis of IMB
#
# This notebook performs data analysis of the csv files created by running the IMB benchmark

# %%
import csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import re

# %%
results = {
    "Cloud_IMB":[],
    "SCARF_IMB":[]
}

for dataName in results:
    with open("../" + dataName + "/out.csv", "r") as fHandle:
        reader = csv.reader(fHandle)  # create an iterator over each row
        headers = next(reader) # the headers are the first line
        latencyIndex = headers.index("Latency")  #
        bandwidthIndex = headers.index("0")  # after hear, all are the bandwidths
        if messageSizes is not None:
            messageSizes = [int(el) for el in headers[bandwidthIndex + 1:]]
        elif messageSizes != [int(el) for el in headers[bandwidthIndex + 1:]]:
            raise ValueError("Different message sizes")
        for row in reader:
            thisRow = dict((header, row[index]) for index, header in enumerate(headers))
            thisRow["Bandwidths"] = [float(el) for el in row[bandwidthIndex + 1:]]
            thisRow["maxBandwidths"] = max(thisRow["Bandwidths"])
            thisRow["meanBandwidths"] = sum(thisRow["Bandwidths"]) / len(thisRow["Bandwidths"])
            results[dataName].append(thisRow)
print("Message Sizes:")
print(messageSizes)
print()
for dataName in results:
    print(dataName)
    print("1st latency:        {}".format(results[dataName][0]["Latency"]))
    print("max bandwidth:      {}".format(max(test["maxBandwidths"] for test in results[dataName])))
    print("1st bandwidths(10): {}".format(results[dataName][0]["Bandwidths"][0:10]))
    print()
# Out:
# Message Sizes:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]
#
# SCARF_IMB
# 1st latency:        0.23
# max bandwidth:      9149.72
# 1st bandwidths(10): [3.98, 7.96, 15.96, 31.86, 63.71, 126.61, 261.36, 311.81, 597.61, 1037.75]
#
# Cloud_IMB
# 1st latency:        0.27
# max bandwidth:      7494.1
# 1st bandwidths(10): [2.56, 5.55, 11.12, 21.93, 39.13, 81.37, 156.72, 256.45, 501.84, 776.35]

# %%
import datetime

#datetime.datetime.strptime(None, "%Y%m%d_%H%M%S.out")

# %%
def plotScarfBandwidth():
    protocols = sorted(set(row["Protocols Seen"] for row in results["SCARF_IMB"]))
    hostgroups = sorted(set(row["Host Groups"] for row in results["SCARF_IMB"]))
    print(protocols)
    print(hostgroups)
    for prot in protocols:
        res = [row for row in results["SCARF_IMB"] if row["Protocols Seen"] == prot]
        clrMap = plt.get_cmap("nipy_spectral")
        legendHandles = []
        for index, row in enumerate(sorted(res, key=lambda el: el["File Name"])):
            band = row["Bandwidths"]
            clr = clrMap(hostgroups.index(row["Host Groups"]) / len(hostgroups))
            clr = (clr[0], clr[1], clr[2], 1)
            plt.plot(messageSizes, band, color=clr, marker="o", linestyle="-")
            nodeNumbers = ",".join(re.findall("cn\d+", row["Hosts Used"]))
            legendHandles.append(mpatches.Patch(color=clr, label="{}_{}".format(row["Host Groups"], nodeNumbers)))
        plt.legend(handles=legendHandles, loc=2, ncol=1)
        plt.rcParams["figure.figsize"] = (20, 20)
        plt.xscale("log", basex=2)
        plt.title("Bandwidth by Message Size for {}".format(prot))
        plt.xlabel("Message Size/Bytes")
        plt.ylabel("Bandwidth/MBs^-1")
        plt.grid(True, which="minor", linestyle="--")
        plt.grid(True, which="major", linestyle="-")
        plt.minorticks_on()
        plt.show()

plotScarfBandwidth()
# Out:
# ['SHM', 'SHM-IBV', 'SHM-TCP']
# ['scarf10', 'scarf10-scarf10', 'scarf11', 'scarf11-scarf11', 'scarf12', 'scarf12-scarf12', 'scarf13', 'scarf13-scarf13', 'scarf14', 'scarf14-scarf14', 'scarf15', 'scarf15-scarf15', 'scarf16', 'scarf16-scarf16']

# %%
def plotLatencies(start, end):
    plt.plot(datesRun[start:end], latencies[start:end], "r.")
    plt.rcParams["figure.figsize"] = (20,20)
    # plt.xscale("log", basex=2)
    # plt.yscale("log")
    plt.title("Latency by Date Run")
    plt.xlabel("Latency" + "/" + "usec")
    plt.ylabel("Date")
    plt.grid(True, which="minor", linestyle="--")
    plt.grid(True, which="major", linestyle="-")
    plt.minorticks_on()
    plt.show()

# plotLatencies(0, len(latencies))

# %%
def plotLatenciesAndMaxBandwidth(start, end):
    fig, ax1 = plt.subplots(figsize=plotSize)
    ax1.plot(datesRun[start:end], latencies[start:end], 'r.')
    ax1.set_xlabel('time (s)')
    ax1.set_ylabel("Latency/usec", color='r')
    ax1.tick_params('y', colors='r')

    ax2 = ax1.twinx()
    ax2.plot(datesRun[start:end], maxBandwidths[start:end], 'g.')
    # ax2.plot(datesRun[start:end], meanBandwidths[start:end], 'b.')
    ax2.set_ylabel("Bandwidth/MBs^-1", color='g')
    ax2.tick_params('y', colors='g')

    plt.title("Latency and Max Bandwidth by Date Run")

    ax1.grid(True, which="minor", linestyle="--")
    ax1.grid(True, which="major", linestyle="-")

    plt.show()
    


plotLatenciesAndMaxBandwidth(0, len(datesRun))

# %%
def plotBandwidthAgainstLatency(start, end):
    plt.plot(latencies[start:end], maxBandwidths[start:end], "r.")
    # plt.plot(latencies[start:end], meanBandwidths[start:end], "g.")
    plt.rcParams["figure.figsize"] = plotSize
    plt.ylabel("Max Bandwidth/MBs^-1")
    plt.xlabel("Latency/usec")
    plt.grid(True, which="minor", linestyle="--")
    plt.grid(True, which="major", linestyle="-")
    plt.minorticks_on()

    plt.title("Bandwidth by Latency")

    plt.show()
    
#     fig, ax1 = plt.subplots(figsize=(20,20))
#     ax1.plot(latencies[start:end], maxBandwidths[start:end], 'r.')
#     ax1.set_xlabel("Latency/usec")
#     ax1.set_ylabel("Max Bandwidth/MBs^-1", color='r')
#     ax1.tick_params('y', colors='r')

#     ax2 = ax1.twinx()
#     ax2.plot(latencies[start:end], meanBandwidths[start:end], 'g.')
#     ax2.set_ylabel("Mean Bandwidth/MBs^-1", color='g')
#     ax2.tick_params('y', colors='g')

#     plt.title("Max and Mean Bandwidth against Latency")

#     ax1.grid(True, which="minor", linestyle="--")
#     ax1.grid(True, which="major", linestyle="-")

#     plt.show()
    


plotBandwidthAgainstLatency(0, len(datesRun))

# %% [markdown]
# The reason that they group into 4 corners rather than 2 is because the job can migrate from one cpu to two cpus half way through, creating a low latency, high MAX bandwidth or a high latency low MAX bandwidth situation

# %%
i = iter(datesRun[240:])
last = next(i)
total = 0
for d in i:
    print(d - last)
    if d - last == datetime.timedelta(0, 900):
        total += 1
    else:
        total = 0
    secondLast = last
    last = d

total
# Out:
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 0:15:00
# 84

# %%
len(datesRun) - 85
# Out:
# 240

# %%
bandwidths
# Out:
# [[0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.12,
#   0.21,
#   0.38,
#   0.87,
#   1.61,
#   3.24,
#   7.14,
#   13.78,
#   17.58,
#   30.33,
#   54.05,
#   112.2,
#   180.08,
#   183.46,
#   272.3,
#   304.99,
#   365.41,
#   403.29,
#   466.49,
#   414.96,
#   397.27,
#   386.32],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.08,
#   0.18,
#   0.45,
#   0.97,
#   0.96,
#   4.03,
#   7.06,
#   14.52,
#   19.53,
#   25.42,
#   50.3,
#   82.85,
#   139.66,
#   147.69,
#   273.39,
#   330.16,
#   362.79,
#   380.35,
#   402.51,
#   366.83,
#   421.06,
#   441.76],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.12,
#   0.25,
#   0.51,
#   1.04,
#   1.95,
#   3.69,
#   7.52,
#   14.02,
#   20.58,
#   37.13,
#   56.29,
#   103.64,
#   173.33,
#   191.87,
#   292.47,
#   295.45,
#   382.34,
#   386.56,
#   401.66,
#   404.01,
#   396.5,
#   414.38],
#  [0.0,
#   0.02,
#   0.03,
#   0.08,
#   0.15,
#   0.26,
#   0.6,
#   1.2,
#   2.37,
#   4.41,
#   5.91,
#   12.18,
#   14.82,
#   38.76,
#   65.57,
#   103.72,
#   181.39,
#   177.3,
#   217.4,
#   354.02,
#   426.2,
#   336.97,
#   343.23,
#   321.87,
#   319.04,
#   383.39],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.09,
#   0.21,
#   0.52,
#   0.71,
#   1.64,
#   2.76,
#   6.62,
#   13.88,
#   17.55,
#   33.13,
#   53.66,
#   104.32,
#   173.6,
#   166.68,
#   243.18,
#   259.08,
#   333.97,
#   370.69,
#   338.97,
#   368.7,
#   409.42,
#   392.81],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.14,
#   0.3,
#   0.6,
#   1.11,
#   2.04,
#   3.65,
#   7.38,
#   13.64,
#   15.55,
#   30.1,
#   58.63,
#   98.56,
#   168.42,
#   181.6,
#   249.89,
#   325.29,
#   399.79,
#   359.04,
#   371.01,
#   410.89,
#   395.6,
#   406.1],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.14,
#   0.34,
#   0.67,
#   1.31,
#   2.62,
#   5.08,
#   9.57,
#   16.83,
#   21.47,
#   40.35,
#   75.35,
#   126.79,
#   207.71,
#   220.23,
#   329.7,
#   346.25,
#   377.23,
#   443.94,
#   439.1,
#   394.05,
#   445.14,
#   442.78],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.13,
#   0.18,
#   0.35,
#   0.77,
#   1.65,
#   2.05,
#   7.74,
#   10.77,
#   16.35,
#   34.73,
#   58.43,
#   93.85,
#   151.26,
#   164.4,
#   189.91,
#   324.24,
#   295.07,
#   362.14,
#   376.68,
#   412.05,
#   380.74,
#   386.87],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.11,
#   0.26,
#   0.57,
#   1.07,
#   2.03,
#   3.26,
#   7.74,
#   14.0,
#   15.71,
#   35.94,
#   60.76,
#   108.3,
#   178.01,
#   166.67,
#   270.67,
#   276.01,
#   340.49,
#   403.71,
#   437.35,
#   367.71,
#   387.93,
#   388.07],
#  [0.0,
#   0.02,
#   0.04,
#   0.08,
#   0.15,
#   0.32,
#   0.59,
#   1.17,
#   2.1,
#   3.89,
#   8.04,
#   15.07,
#   22.2,
#   40.47,
#   62.49,
#   112.84,
#   180.12,
#   190.73,
#   289.32,
#   330.49,
#   411.66,
#   462.96,
#   422.59,
#   403.17,
#   402.2,
#   438.0],
#  [0.0,
#   0.02,
#   0.04,
#   0.07,
#   0.14,
#   0.28,
#   0.5,
#   1.25,
#   2.1,
#   4.79,
#   9.02,
#   16.04,
#   20.98,
#   40.22,
#   72.44,
#   118.82,
#   191.77,
#   205.15,
#   301.09,
#   335.0,
#   350.12,
#   392.61,
#   455.61,
#   394.46,
#   418.21,
#   413.2],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.12,
#   0.23,
#   0.32,
#   0.66,
#   1.97,
#   3.62,
#   5.21,
#   15.94,
#   20.37,
#   26.63,
#   62.03,
#   88.7,
#   161.41,
#   151.63,
#   236.67,
#   278.3,
#   296.41,
#   266.32,
#   297.39,
#   303.85,
#   328.05,
#   309.77],
#  [0.0,
#   0.02,
#   0.02,
#   0.05,
#   0.14,
#   0.3,
#   0.43,
#   1.1,
#   1.92,
#   3.57,
#   6.25,
#   10.89,
#   16.97,
#   34.61,
#   58.69,
#   111.0,
#   184.48,
#   172.0,
#   299.04,
#   301.19,
#   368.5,
#   395.81,
#   371.31,
#   396.98,
#   353.35,
#   346.48],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.11,
#   0.22,
#   0.35,
#   0.73,
#   1.57,
#   2.36,
#   7.79,
#   13.94,
#   19.79,
#   27.64,
#   54.77,
#   91.29,
#   169.11,
#   139.56,
#   223.12,
#   291.49,
#   321.77,
#   330.87,
#   334.69,
#   343.96,
#   349.66,
#   392.09],
#  [0.0,
#   0.01,
#   0.02,
#   0.06,
#   0.08,
#   0.22,
#   0.45,
#   0.82,
#   1.91,
#   3.39,
#   6.35,
#   12.95,
#   15.92,
#   29.71,
#   51.25,
#   100.78,
#   173.19,
#   155.85,
#   199.93,
#   291.23,
#   322.58,
#   372.28,
#   356.02,
#   321.98,
#   331.12,
#   358.89],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.11,
#   0.19,
#   0.44,
#   0.64,
#   2.13,
#   4.35,
#   8.54,
#   14.97,
#   13.68,
#   24.5,
#   61.37,
#   100.09,
#   177.02,
#   192.47,
#   259.13,
#   314.8,
#   370.69,
#   324.79,
#   380.01,
#   381.68,
#   373.89,
#   372.36],
#  [0.0,
#   0.02,
#   0.03,
#   0.05,
#   0.12,
#   0.19,
#   0.41,
#   0.72,
#   1.88,
#   3.61,
#   7.52,
#   14.87,
#   20.47,
#   38.49,
#   63.6,
#   111.53,
#   157.25,
#   179.8,
#   259.32,
#   320.52,
#   360.77,
#   347.45,
#   394.94,
#   420.41,
#   407.78,
#   435.28],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.14,
#   0.27,
#   0.48,
#   1.06,
#   2.21,
#   4.1,
#   8.26,
#   13.18,
#   22.2,
#   33.51,
#   51.95,
#   106.0,
#   165.26,
#   131.57,
#   239.37,
#   259.19,
#   325.42,
#   379.02,
#   367.5,
#   369.88,
#   367.09,
#   394.8],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.12,
#   0.29,
#   0.58,
#   0.89,
#   2.15,
#   2.99,
#   7.05,
#   13.42,
#   20.01,
#   38.81,
#   60.16,
#   106.61,
#   147.93,
#   175.88,
#   224.69,
#   301.72,
#   345.08,
#   362.83,
#   370.73,
#   392.37,
#   370.93,
#   377.59],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.15,
#   0.27,
#   0.59,
#   1.07,
#   2.2,
#   4.08,
#   8.75,
#   16.4,
#   21.28,
#   41.15,
#   70.04,
#   113.34,
#   187.44,
#   200.22,
#   299.9,
#   290.08,
#   386.0,
#   418.03,
#   436.74,
#   417.58,
#   401.63,
#   390.08],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.1,
#   0.2,
#   0.59,
#   0.85,
#   1.82,
#   3.62,
#   8.56,
#   14.44,
#   19.87,
#   27.59,
#   72.43,
#   101.53,
#   135.09,
#   182.51,
#   204.4,
#   300.71,
#   333.55,
#   459.57,
#   469.96,
#   438.27,
#   435.25,
#   436.47],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.12,
#   0.21,
#   0.42,
#   0.78,
#   1.88,
#   3.25,
#   5.95,
#   12.44,
#   14.04,
#   29.36,
#   56.07,
#   94.26,
#   148.21,
#   154.84,
#   215.81,
#   262.35,
#   322.96,
#   373.48,
#   350.41,
#   427.24,
#   383.01,
#   396.21],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.12,
#   0.21,
#   0.39,
#   0.81,
#   1.66,
#   3.8,
#   6.07,
#   14.64,
#   14.68,
#   28.04,
#   48.83,
#   79.08,
#   138.22,
#   152.47,
#   266.14,
#   327.11,
#   345.51,
#   418.16,
#   431.93,
#   396.38,
#   415.42,
#   401.34],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.14,
#   0.2,
#   0.48,
#   0.77,
#   1.7,
#   4.66,
#   4.01,
#   12.76,
#   18.94,
#   30.47,
#   54.0,
#   116.37,
#   180.09,
#   160.24,
#   269.79,
#   308.14,
#   306.88,
#   337.43,
#   348.93,
#   329.74,
#   388.38,
#   355.96],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.12,
#   0.26,
#   0.54,
#   1.02,
#   1.8,
#   3.66,
#   7.95,
#   14.59,
#   18.11,
#   33.84,
#   74.7,
#   106.02,
#   174.61,
#   180.16,
#   241.09,
#   304.14,
#   351.37,
#   411.22,
#   409.71,
#   413.12,
#   439.49,
#   444.36],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.13,
#   0.24,
#   0.4,
#   0.82,
#   1.65,
#   3.18,
#   6.39,
#   13.69,
#   14.87,
#   31.26,
#   56.14,
#   87.76,
#   156.98,
#   155.08,
#   237.82,
#   276.67,
#   366.23,
#   427.34,
#   336.75,
#   378.8,
#   398.52,
#   379.89],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.09,
#   0.21,
#   0.45,
#   0.89,
#   1.76,
#   3.57,
#   5.72,
#   11.54,
#   17.57,
#   33.52,
#   63.36,
#   99.68,
#   159.3,
#   161.3,
#   261.76,
#   300.31,
#   377.63,
#   375.9,
#   332.99,
#   414.56,
#   363.74,
#   401.45],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.14,
#   0.29,
#   0.26,
#   0.85,
#   2.31,
#   4.05,
#   7.62,
#   15.86,
#   20.68,
#   25.43,
#   63.29,
#   109.63,
#   133.39,
#   152.62,
#   225.25,
#   276.46,
#   361.46,
#   346.93,
#   354.02,
#   386.03,
#   418.97,
#   387.22],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.12,
#   0.25,
#   0.46,
#   0.8,
#   1.51,
#   3.98,
#   8.13,
#   14.14,
#   17.7,
#   29.66,
#   57.44,
#   68.43,
#   110.42,
#   170.21,
#   244.81,
#   270.84,
#   345.8,
#   347.49,
#   417.7,
#   356.27,
#   352.85,
#   347.44],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.11,
#   0.18,
#   0.41,
#   0.9,
#   1.1,
#   3.77,
#   6.7,
#   12.91,
#   18.98,
#   31.56,
#   60.81,
#   100.12,
#   113.61,
#   154.14,
#   229.88,
#   333.13,
#   362.34,
#   338.8,
#   315.71,
#   293.28,
#   291.48,
#   321.24],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.12,
#   0.29,
#   0.51,
#   1.03,
#   1.86,
#   3.78,
#   7.33,
#   15.2,
#   20.73,
#   37.33,
#   65.94,
#   116.16,
#   184.26,
#   197.12,
#   259.0,
#   310.77,
#   363.58,
#   386.43,
#   356.97,
#   416.44,
#   380.44,
#   402.3],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.11,
#   0.18,
#   0.53,
#   0.99,
#   1.81,
#   3.52,
#   7.21,
#   13.31,
#   14.72,
#   36.37,
#   61.45,
#   103.98,
#   155.09,
#   153.96,
#   226.45,
#   275.25,
#   313.34,
#   343.01,
#   349.74,
#   374.12,
#   349.82,
#   374.46],
#  [0.0,
#   0.02,
#   0.02,
#   0.06,
#   0.12,
#   0.19,
#   0.55,
#   0.99,
#   1.96,
#   3.09,
#   7.25,
#   10.21,
#   17.36,
#   31.36,
#   38.91,
#   103.23,
#   149.77,
#   178.73,
#   278.35,
#   312.52,
#   367.42,
#   394.61,
#   357.27,
#   386.3,
#   443.68,
#   459.81],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.08,
#   0.23,
#   0.45,
#   1.0,
#   2.05,
#   4.25,
#   7.64,
#   13.87,
#   20.02,
#   38.11,
#   69.21,
#   111.95,
#   160.05,
#   179.59,
#   275.0,
#   321.63,
#   327.87,
#   423.17,
#   406.79,
#   409.73,
#   379.43,
#   383.56],
#  [0.0,
#   0.02,
#   0.04,
#   0.07,
#   0.14,
#   0.26,
#   0.52,
#   1.16,
#   1.9,
#   3.95,
#   8.25,
#   14.15,
#   19.45,
#   33.1,
#   69.34,
#   108.29,
#   163.59,
#   184.64,
#   285.38,
#   332.62,
#   407.56,
#   392.66,
#   378.35,
#   423.25,
#   396.15,
#   410.55],
#  [0.0,
#   0.02,
#   0.04,
#   0.07,
#   0.13,
#   0.26,
#   0.52,
#   1.05,
#   1.92,
#   3.99,
#   7.24,
#   14.84,
#   20.04,
#   36.03,
#   66.88,
#   117.49,
#   188.69,
#   201.05,
#   279.72,
#   341.71,
#   353.86,
#   380.87,
#   394.83,
#   397.24,
#   402.51,
#   470.72],
#  [0.0,
#   0.02,
#   0.03,
#   0.05,
#   0.09,
#   0.25,
#   0.47,
#   0.77,
#   1.86,
#   4.15,
#   6.75,
#   13.61,
#   17.76,
#   30.7,
#   55.27,
#   104.37,
#   165.01,
#   124.15,
#   193.75,
#   269.9,
#   318.79,
#   365.73,
#   406.85,
#   363.36,
#   390.56,
#   390.98],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.11,
#   0.16,
#   0.53,
#   1.12,
#   1.82,
#   2.86,
#   5.63,
#   13.91,
#   17.52,
#   35.3,
#   67.31,
#   114.9,
#   184.33,
#   167.47,
#   239.01,
#   275.22,
#   309.09,
#   349.0,
#   378.65,
#   336.9,
#   436.08,
#   423.39],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.13,
#   0.34,
#   0.45,
#   0.72,
#   1.25,
#   2.99,
#   5.39,
#   14.84,
#   16.94,
#   31.63,
#   54.03,
#   91.26,
#   124.42,
#   141.91,
#   226.0,
#   267.89,
#   320.57,
#   337.25,
#   346.89,
#   380.95,
#   402.4,
#   379.19],
#  [0.0,
#   0.01,
#   0.02,
#   0.04,
#   0.13,
#   0.18,
#   0.3,
#   0.91,
#   1.84,
#   3.39,
#   7.32,
#   12.38,
#   15.05,
#   34.32,
#   53.14,
#   90.85,
#   130.67,
#   161.3,
#   217.52,
#   301.48,
#   317.7,
#   360.11,
#   380.2,
#   335.76,
#   346.35,
#   357.37],
#  [0.0,
#   0.02,
#   0.03,
#   0.05,
#   0.12,
#   0.17,
#   0.43,
#   0.61,
#   1.62,
#   3.57,
#   6.35,
#   14.83,
#   17.3,
#   31.33,
#   47.76,
#   87.36,
#   148.56,
#   169.47,
#   251.47,
#   276.82,
#   304.71,
#   370.7,
#   365.33,
#   411.69,
#   357.62,
#   342.98],
#  [0.0,
#   0.02,
#   0.02,
#   0.05,
#   0.13,
#   0.24,
#   0.4,
#   1.02,
#   2.24,
#   4.09,
#   6.25,
#   13.22,
#   19.2,
#   36.59,
#   52.44,
#   108.32,
#   151.37,
#   153.84,
#   240.56,
#   299.05,
#   362.96,
#   351.67,
#   385.77,
#   441.98,
#   433.01,
#   398.57],
#  [0.0,
#   0.02,
#   0.04,
#   0.07,
#   0.15,
#   0.3,
#   0.59,
#   1.04,
#   2.08,
#   4.43,
#   8.68,
#   15.76,
#   20.0,
#   37.29,
#   70.51,
#   108.57,
#   202.51,
#   221.54,
#   321.37,
#   371.31,
#   397.94,
#   413.93,
#   444.89,
#   426.76,
#   437.59,
#   461.93],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.14,
#   0.22,
#   0.56,
#   1.16,
#   2.28,
#   3.58,
#   6.57,
#   14.5,
#   19.35,
#   38.93,
#   72.86,
#   96.54,
#   162.5,
#   157.07,
#   264.62,
#   284.82,
#   358.97,
#   406.99,
#   354.85,
#   417.18,
#   374.32,
#   379.87],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.11,
#   0.23,
#   0.48,
#   0.91,
#   1.97,
#   4.25,
#   7.57,
#   15.85,
#   18.24,
#   33.09,
#   59.27,
#   103.34,
#   169.62,
#   186.0,
#   233.41,
#   281.88,
#   318.43,
#   377.66,
#   383.71,
#   377.84,
#   380.96,
#   386.45],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.12,
#   0.27,
#   0.55,
#   1.08,
#   2.07,
#   4.17,
#   8.38,
#   13.33,
#   18.27,
#   32.63,
#   65.47,
#   117.74,
#   177.11,
#   168.88,
#   261.55,
#   273.55,
#   299.1,
#   337.57,
#   307.7,
#   341.02,
#   343.6,
#   359.05],
#  [0.0,
#   0.02,
#   0.04,
#   0.07,
#   0.16,
#   0.3,
#   0.62,
#   1.2,
#   2.42,
#   4.76,
#   8.96,
#   16.28,
#   21.63,
#   42.82,
#   81.54,
#   124.77,
#   187.01,
#   198.88,
#   251.82,
#   316.2,
#   345.83,
#   387.14,
#   434.63,
#   439.89,
#   431.55,
#   425.99],
#  [0.0,
#   0.01,
#   0.02,
#   0.05,
#   0.11,
#   0.26,
#   0.51,
#   1.09,
#   1.96,
#   3.32,
#   6.44,
#   15.43,
#   10.45,
#   32.07,
#   67.49,
#   79.92,
#   138.53,
#   176.52,
#   266.57,
#   313.65,
#   303.38,
#   381.41,
#   376.05,
#   393.95,
#   387.77,
#   407.92],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.12,
#   0.23,
#   0.48,
#   0.86,
#   1.74,
#   3.73,
#   7.06,
#   12.85,
#   17.81,
#   35.93,
#   53.8,
#   107.38,
#   176.32,
#   164.53,
#   293.43,
#   413.41,
#   503.92,
#   391.16,
#   432.86,
#   400.3,
#   427.18,
#   430.73],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.12,
#   0.23,
#   0.47,
#   1.05,
#   1.99,
#   2.92,
#   6.58,
#   13.43,
#   18.17,
#   32.43,
#   74.26,
#   104.53,
#   165.9,
#   175.83,
#   250.25,
#   305.04,
#   356.82,
#   396.7,
#   440.04,
#   368.53,
#   360.41,
#   393.17],
#  [0.0,
#   0.01,
#   0.02,
#   0.05,
#   0.09,
#   0.27,
#   0.36,
#   0.85,
#   1.67,
#   3.48,
#   6.25,
#   12.8,
#   20.59,
#   27.13,
#   58.8,
#   85.94,
#   129.94,
#   172.17,
#   252.08,
#   266.6,
#   338.13,
#   358.28,
#   330.3,
#   365.62,
#   386.38,
#   376.93],
#  [0.0,
#   0.02,
#   0.04,
#   0.07,
#   0.14,
#   0.26,
#   0.47,
#   1.04,
#   1.98,
#   3.52,
#   7.84,
#   14.36,
#   18.81,
#   35.28,
#   69.31,
#   102.32,
#   169.14,
#   178.19,
#   288.92,
#   315.83,
#   386.94,
#   398.22,
#   390.98,
#   379.77,
#   400.58,
#   394.25],
#  [0.0,
#   0.01,
#   0.02,
#   0.05,
#   0.08,
#   0.14,
#   0.38,
#   0.89,
#   1.58,
#   3.29,
#   6.64,
#   10.06,
#   13.61,
#   30.15,
#   45.97,
#   89.28,
#   149.72,
#   163.18,
#   258.28,
#   273.67,
#   319.97,
#   342.6,
#   353.69,
#   353.46,
#   335.12,
#   362.44],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.11,
#   0.27,
#   0.49,
#   0.82,
#   1.8,
#   3.52,
#   4.96,
#   8.55,
#   18.48,
#   30.3,
#   57.05,
#   86.29,
#   124.86,
#   151.56,
#   242.01,
#   301.29,
#   330.26,
#   394.0,
#   327.8,
#   352.96,
#   352.18,
#   371.79],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.13,
#   0.28,
#   0.5,
#   1.01,
#   2.1,
#   3.82,
#   7.65,
#   14.09,
#   21.63,
#   37.09,
#   70.51,
#   105.91,
#   176.97,
#   177.96,
#   259.5,
#   329.42,
#   373.15,
#   416.59,
#   439.37,
#   384.14,
#   402.8,
#   428.47],
#  [0.0,
#   0.01,
#   0.03,
#   0.04,
#   0.09,
#   0.2,
#   0.43,
#   0.87,
#   1.84,
#   3.07,
#   4.54,
#   15.15,
#   20.06,
#   25.09,
#   64.93,
#   110.23,
#   179.28,
#   181.66,
#   263.95,
#   322.68,
#   408.74,
#   398.62,
#   389.14,
#   436.13,
#   462.62,
#   450.01],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.12,
#   0.23,
#   0.37,
#   0.8,
#   1.69,
#   3.43,
#   6.59,
#   13.8,
#   18.85,
#   28.69,
#   59.91,
#   96.74,
#   159.69,
#   184.29,
#   224.4,
#   322.82,
#   343.22,
#   375.79,
#   441.41,
#   434.99,
#   432.4,
#   437.21],
#  [0.0,
#   0.01,
#   0.03,
#   0.04,
#   0.11,
#   0.26,
#   0.58,
#   1.06,
#   1.73,
#   3.4,
#   6.14,
#   12.42,
#   12.64,
#   24.17,
#   46.62,
#   90.91,
#   133.61,
#   166.12,
#   239.64,
#   276.69,
#   340.13,
#   344.01,
#   361.32,
#   416.49,
#   375.02,
#   365.17],
#  [0.0,
#   0.01,
#   0.02,
#   0.06,
#   0.1,
#   0.2,
#   0.45,
#   0.86,
#   1.98,
#   3.51,
#   6.89,
#   13.9,
#   15.87,
#   31.95,
#   61.92,
#   89.47,
#   163.81,
#   175.97,
#   238.43,
#   307.18,
#   309.34,
#   347.79,
#   350.03,
#   356.86,
#   382.3,
#   393.59],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.14,
#   0.27,
#   0.55,
#   0.8,
#   1.65,
#   4.02,
#   7.19,
#   14.25,
#   19.11,
#   38.35,
#   57.99,
#   105.91,
#   165.47,
#   174.52,
#   264.9,
#   314.78,
#   358.12,
#   389.57,
#   394.45,
#   383.8,
#   358.68,
#   346.78],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.12,
#   0.22,
#   0.39,
#   0.94,
#   1.61,
#   2.81,
#   5.54,
#   13.86,
#   18.79,
#   30.92,
#   43.77,
#   87.19,
#   155.91,
#   176.37,
#   260.4,
#   301.39,
#   291.94,
#   336.01,
#   338.87,
#   426.76,
#   355.99,
#   355.84],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.12,
#   0.27,
#   0.45,
#   0.84,
#   1.64,
#   3.12,
#   7.53,
#   14.72,
#   18.18,
#   37.35,
#   69.97,
#   108.8,
#   175.19,
#   173.39,
#   236.26,
#   268.94,
#   310.82,
#   359.99,
#   378.75,
#   361.22,
#   390.36,
#   412.64],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.1,
#   0.18,
#   0.55,
#   0.74,
#   1.53,
#   4.52,
#   8.85,
#   15.3,
#   17.05,
#   35.23,
#   64.13,
#   105.18,
#   174.47,
#   183.55,
#   259.37,
#   301.38,
#   345.07,
#   367.22,
#   339.22,
#   397.29,
#   371.65,
#   388.21],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.1,
#   0.26,
#   0.45,
#   1.07,
#   1.84,
#   3.77,
#   8.98,
#   14.1,
#   17.2,
#   38.01,
#   56.34,
#   106.93,
#   168.8,
#   168.86,
#   272.41,
#   326.23,
#   344.45,
#   402.59,
#   382.69,
#   371.22,
#   386.56,
#   373.74],
#  [0.0,
#   0.02,
#   0.03,
#   0.08,
#   0.12,
#   0.22,
#   0.44,
#   0.97,
#   2.2,
#   3.22,
#   6.76,
#   11.45,
#   18.51,
#   30.55,
#   58.89,
#   96.79,
#   171.9,
#   187.76,
#   235.73,
#   313.31,
#   425.32,
#   388.4,
#   352.68,
#   446.69,
#   436.68,
#   379.25],
#  [0.0,
#   0.01,
#   0.03,
#   0.04,
#   0.1,
#   0.22,
#   0.35,
#   0.79,
#   1.68,
#   3.01,
#   5.84,
#   12.88,
#   14.78,
#   29.65,
#   51.14,
#   88.89,
#   147.65,
#   153.25,
#   226.34,
#   283.11,
#   340.78,
#   361.07,
#   384.83,
#   405.33,
#   364.66,
#   424.65],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.15,
#   0.28,
#   0.56,
#   1.21,
#   2.36,
#   4.56,
#   7.82,
#   15.7,
#   20.2,
#   42.37,
#   77.44,
#   120.15,
#   174.79,
#   210.54,
#   301.12,
#   338.84,
#   364.72,
#   353.7,
#   406.07,
#   400.81,
#   442.01,
#   423.03],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.13,
#   0.25,
#   0.39,
#   0.89,
#   1.73,
#   2.62,
#   6.16,
#   11.75,
#   18.39,
#   27.24,
#   61.24,
#   106.22,
#   146.07,
#   161.93,
#   213.94,
#   278.34,
#   370.18,
#   344.11,
#   370.2,
#   365.74,
#   376.63,
#   365.61],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.12,
#   0.28,
#   0.48,
#   0.88,
#   1.4,
#   2.78,
#   3.93,
#   11.81,
#   15.68,
#   28.92,
#   58.06,
#   91.85,
#   142.59,
#   143.54,
#   251.59,
#   265.22,
#   303.75,
#   340.84,
#   382.08,
#   394.79,
#   375.47,
#   385.04],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.12,
#   0.27,
#   0.54,
#   0.98,
#   1.92,
#   3.58,
#   8.24,
#   14.82,
#   19.93,
#   36.43,
#   72.11,
#   103.97,
#   177.05,
#   191.48,
#   251.51,
#   305.73,
#   361.47,
#   358.29,
#   440.54,
#   368.15,
#   395.96,
#   402.38],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.15,
#   0.28,
#   0.58,
#   1.2,
#   2.35,
#   4.28,
#   8.43,
#   15.05,
#   19.01,
#   35.35,
#   65.69,
#   116.14,
#   200.59,
#   184.1,
#   266.88,
#   336.7,
#   394.99,
#   420.47,
#   452.03,
#   384.9,
#   411.43,
#   379.6],
#  [0.0,
#   0.01,
#   0.03,
#   0.03,
#   0.11,
#   0.27,
#   0.49,
#   0.64,
#   1.22,
#   4.24,
#   4.26,
#   14.62,
#   18.26,
#   34.76,
#   54.04,
#   104.05,
#   172.42,
#   190.96,
#   239.07,
#   314.55,
#   363.53,
#   392.0,
#   384.27,
#   382.68,
#   343.65,
#   344.94],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.11,
#   0.2,
#   0.47,
#   0.99,
#   1.89,
#   3.95,
#   6.2,
#   13.12,
#   18.56,
#   32.73,
#   58.05,
#   105.95,
#   168.15,
#   179.1,
#   285.39,
#   309.27,
#   358.39,
#   415.47,
#   440.97,
#   377.78,
#   374.71,
#   396.79],
#  [0.0,
#   0.02,
#   0.04,
#   0.05,
#   0.12,
#   0.28,
#   0.52,
#   1.07,
#   1.37,
#   3.21,
#   7.26,
#   13.3,
#   16.09,
#   33.74,
#   63.58,
#   113.83,
#   173.07,
#   191.85,
#   266.55,
#   321.8,
#   404.18,
#   420.75,
#   432.43,
#   379.5,
#   427.27,
#   411.77],
#  [0.0,
#   0.02,
#   0.03,
#   0.05,
#   0.14,
#   0.26,
#   0.45,
#   0.72,
#   1.67,
#   2.79,
#   7.36,
#   12.67,
#   18.31,
#   37.3,
#   62.34,
#   101.13,
#   163.19,
#   174.72,
#   278.01,
#   312.87,
#   371.15,
#   393.1,
#   399.7,
#   392.94,
#   374.05,
#   454.67],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.13,
#   0.25,
#   0.47,
#   0.95,
#   1.35,
#   3.8,
#   8.13,
#   15.28,
#   21.69,
#   36.51,
#   73.66,
#   118.93,
#   182.58,
#   206.02,
#   319.01,
#   328.3,
#   389.31,
#   377.05,
#   360.2,
#   380.88,
#   400.7,
#   388.12],
#  [0.0,
#   0.02,
#   0.03,
#   0.04,
#   0.14,
#   0.22,
#   0.42,
#   0.58,
#   1.21,
#   3.38,
#   7.13,
#   11.71,
#   14.7,
#   32.69,
#   48.78,
#   95.86,
#   159.84,
#   192.0,
#   219.78,
#   307.47,
#   350.07,
#   348.85,
#   352.74,
#   366.95,
#   391.44,
#   398.64],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.12,
#   0.28,
#   0.54,
#   1.09,
#   1.66,
#   4.47,
#   7.59,
#   13.67,
#   20.24,
#   30.98,
#   62.04,
#   111.0,
#   167.71,
#   158.4,
#   254.0,
#   310.57,
#   412.98,
#   388.76,
#   450.81,
#   427.74,
#   414.68,
#   411.71],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.14,
#   0.23,
#   0.43,
#   1.11,
#   2.22,
#   4.2,
#   8.42,
#   15.66,
#   18.94,
#   35.75,
#   73.21,
#   115.26,
#   172.95,
#   172.01,
#   285.67,
#   320.75,
#   344.72,
#   399.87,
#   386.68,
#   360.13,
#   342.85,
#   338.04],
#  [0.0,
#   0.02,
#   0.03,
#   0.04,
#   0.12,
#   0.21,
#   0.46,
#   0.81,
#   1.81,
#   3.55,
#   6.45,
#   15.46,
#   18.69,
#   33.92,
#   65.04,
#   94.03,
#   146.02,
#   167.18,
#   238.98,
#   285.7,
#   372.6,
#   388.44,
#   387.05,
#   392.93,
#   419.97,
#   407.59],
#  [0.0,
#   0.01,
#   0.02,
#   0.06,
#   0.12,
#   0.14,
#   0.32,
#   0.81,
#   2.1,
#   3.33,
#   6.99,
#   13.52,
#   17.68,
#   32.71,
#   56.07,
#   76.87,
#   164.6,
#   180.39,
#   225.9,
#   333.23,
#   355.88,
#   363.68,
#   289.78,
#   367.61,
#   369.26,
#   412.02],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.1,
#   0.21,
#   0.57,
#   0.97,
#   2.38,
#   4.03,
#   8.43,
#   14.68,
#   18.47,
#   38.53,
#   63.75,
#   109.4,
#   175.18,
#   165.03,
#   261.09,
#   275.61,
#   314.1,
#   366.78,
#   386.58,
#   336.63,
#   339.13,
#   394.19],
#  [0.0,
#   0.01,
#   0.04,
#   0.07,
#   0.15,
#   0.26,
#   0.52,
#   0.94,
#   1.95,
#   3.54,
#   7.8,
#   14.21,
#   18.49,
#   33.47,
#   57.89,
#   103.08,
#   155.61,
#   185.5,
#   235.24,
#   294.66,
#   378.25,
#   355.74,
#   392.4,
#   410.29,
#   405.16,
#   427.79],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.12,
#   0.26,
#   0.46,
#   0.87,
#   1.88,
#   4.0,
#   7.88,
#   10.64,
#   18.78,
#   37.35,
#   55.79,
#   87.29,
#   139.76,
#   146.65,
#   230.41,
#   269.62,
#   354.96,
#   386.48,
#   333.27,
#   347.8,
#   333.48,
#   341.92],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.12,
#   0.26,
#   0.51,
#   1.01,
#   2.24,
#   4.7,
#   8.48,
#   16.28,
#   22.17,
#   37.77,
#   71.13,
#   121.74,
#   189.1,
#   194.82,
#   291.39,
#   357.92,
#   415.42,
#   447.85,
#   420.73,
#   403.45,
#   417.92,
#   420.74],
#  [0.0,
#   0.01,
#   0.02,
#   0.06,
#   0.11,
#   0.23,
#   0.46,
#   0.89,
#   1.93,
#   3.67,
#   7.09,
#   13.3,
#   16.07,
#   33.14,
#   51.29,
#   88.69,
#   164.7,
#   155.54,
#   251.42,
#   283.39,
#   379.46,
#   379.03,
#   394.7,
#   355.5,
#   426.15,
#   420.41],
#  [0.0,
#   0.01,
#   0.03,
#   0.04,
#   0.1,
#   0.2,
#   0.43,
#   0.94,
#   1.69,
#   3.24,
#   6.85,
#   12.72,
#   16.8,
#   38.13,
#   57.45,
#   110.79,
#   170.18,
#   177.25,
#   265.42,
#   321.63,
#   379.96,
#   380.31,
#   413.72,
#   330.57,
#   389.88,
#   358.42],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.13,
#   0.25,
#   0.52,
#   0.79,
#   1.69,
#   3.1,
#   5.4,
#   9.78,
#   18.73,
#   37.5,
#   53.64,
#   98.35,
#   154.5,
#   151.54,
#   212.97,
#   305.13,
#   306.87,
#   388.96,
#   345.54,
#   411.01,
#   367.37,
#   373.43],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.08,
#   0.2,
#   0.58,
#   0.96,
#   2.18,
#   3.84,
#   5.85,
#   10.38,
#   17.4,
#   29.38,
#   48.36,
#   107.48,
#   178.63,
#   168.89,
#   284.68,
#   316.25,
#   350.63,
#   342.94,
#   359.1,
#   375.52,
#   393.38,
#   380.25],
#  [0.0,
#   0.01,
#   0.03,
#   0.04,
#   0.13,
#   0.26,
#   0.6,
#   1.24,
#   2.1,
#   3.85,
#   4.06,
#   14.1,
#   21.25,
#   36.13,
#   50.24,
#   113.57,
#   134.9,
#   166.62,
#   270.26,
#   270.94,
#   307.74,
#   347.36,
#   395.75,
#   368.07,
#   387.49,
#   399.86],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.11,
#   0.21,
#   0.4,
#   0.83,
#   1.98,
#   4.14,
#   6.4,
#   13.46,
#   17.53,
#   32.34,
#   53.68,
#   98.08,
#   147.31,
#   171.21,
#   266.87,
#   248.8,
#   349.48,
#   357.58,
#   392.87,
#   291.5,
#   341.73,
#   336.33],
#  [0.0,
#   0.02,
#   0.04,
#   0.07,
#   0.14,
#   0.28,
#   0.55,
#   1.0,
#   2.14,
#   4.5,
#   9.06,
#   16.4,
#   22.19,
#   36.92,
#   68.76,
#   114.53,
#   187.93,
#   209.8,
#   308.47,
#   355.32,
#   368.61,
#   434.36,
#   455.87,
#   402.41,
#   391.19,
#   441.39],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.14,
#   0.27,
#   0.58,
#   1.09,
#   2.22,
#   4.34,
#   8.31,
#   16.24,
#   22.32,
#   42.0,
#   79.64,
#   116.1,
#   182.99,
#   185.78,
#   279.82,
#   294.99,
#   420.26,
#   432.09,
#   431.7,
#   396.38,
#   424.9,
#   422.92],
#  [0.0,
#   0.01,
#   0.03,
#   0.04,
#   0.14,
#   0.26,
#   0.48,
#   1.02,
#   1.44,
#   3.38,
#   8.13,
#   10.95,
#   17.73,
#   36.53,
#   57.2,
#   115.75,
#   176.97,
#   187.27,
#   281.86,
#   362.31,
#   376.84,
#   388.17,
#   364.18,
#   369.24,
#   378.13,
#   402.1],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.1,
#   0.24,
#   0.45,
#   0.96,
#   1.83,
#   3.48,
#   5.73,
#   12.22,
#   15.12,
#   30.38,
#   54.31,
#   93.22,
#   163.12,
#   163.49,
#   247.91,
#   288.63,
#   361.03,
#   335.71,
#   353.57,
#   418.74,
#   402.2,
#   353.58],
#  [0.0,
#   0.02,
#   0.02,
#   0.03,
#   0.05,
#   0.21,
#   0.25,
#   0.54,
#   0.88,
#   2.47,
#   5.93,
#   7.96,
#   17.05,
#   21.94,
#   40.03,
#   79.0,
#   143.78,
#   182.3,
#   215.51,
#   288.17,
#   296.89,
#   275.97,
#   308.24,
#   336.67,
#   298.56,
#   372.73],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.14,
#   0.26,
#   0.46,
#   1.1,
#   2.03,
#   3.56,
#   7.99,
#   13.42,
#   17.89,
#   32.11,
#   48.32,
#   107.9,
#   169.37,
#   121.43,
#   259.97,
#   284.51,
#   333.21,
#   332.7,
#   393.63,
#   353.3,
#   398.4,
#   405.97],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.13,
#   0.24,
#   0.55,
#   1.11,
#   2.24,
#   3.92,
#   8.52,
#   15.85,
#   22.1,
#   35.09,
#   76.81,
#   104.32,
#   181.91,
#   199.03,
#   301.27,
#   338.7,
#   404.05,
#   429.03,
#   441.66,
#   407.26,
#   405.58,
#   413.99],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.13,
#   0.21,
#   0.48,
#   0.9,
#   1.56,
#   3.01,
#   6.99,
#   13.62,
#   18.93,
#   35.52,
#   52.91,
#   91.8,
#   140.85,
#   165.19,
#   262.77,
#   308.54,
#   316.67,
#   359.59,
#   356.58,
#   418.45,
#   346.7,
#   397.78],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.11,
#   0.14,
#   0.33,
#   0.61,
#   1.76,
#   1.9,
#   5.04,
#   12.53,
#   12.3,
#   22.02,
#   45.96,
#   90.38,
#   126.52,
#   122.12,
#   205.43,
#   261.82,
#   287.66,
#   313.05,
#   301.24,
#   323.06,
#   322.55,
#   310.62],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.09,
#   0.22,
#   0.38,
#   0.95,
#   1.58,
#   3.9,
#   7.98,
#   14.13,
#   20.83,
#   34.46,
#   72.56,
#   110.72,
#   161.24,
#   182.3,
#   274.86,
#   289.32,
#   321.36,
#   369.5,
#   337.81,
#   348.17,
#   349.01,
#   409.88],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.12,
#   0.25,
#   0.5,
#   0.88,
#   1.95,
#   3.74,
#   8.62,
#   12.63,
#   17.3,
#   34.76,
#   67.29,
#   119.81,
#   183.37,
#   197.63,
#   279.84,
#   329.99,
#   384.14,
#   449.72,
#   403.87,
#   370.9,
#   386.32,
#   384.37],
#  [0.0,
#   0.01,
#   0.02,
#   0.05,
#   0.1,
#   0.17,
#   0.38,
#   0.77,
#   1.43,
#   3.87,
#   7.18,
#   14.47,
#   15.06,
#   31.05,
#   58.58,
#   100.68,
#   158.42,
#   168.98,
#   238.73,
#   308.93,
#   391.5,
#   405.04,
#   391.29,
#   308.7,
#   305.66,
#   348.4],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.11,
#   0.24,
#   0.51,
#   1.03,
#   2.01,
#   3.22,
#   7.43,
#   11.4,
#   18.6,
#   30.3,
#   56.7,
#   100.24,
#   176.41,
#   176.77,
#   271.21,
#   325.56,
#   360.84,
#   405.32,
#   371.32,
#   350.28,
#   387.6,
#   378.13],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.13,
#   0.24,
#   0.44,
#   0.81,
#   1.78,
#   4.26,
#   7.65,
#   12.22,
#   19.69,
#   37.97,
#   69.17,
#   110.67,
#   163.23,
#   148.3,
#   285.72,
#   308.62,
#   387.11,
#   395.76,
#   445.28,
#   459.88,
#   398.8,
#   406.84],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.13,
#   0.21,
#   0.44,
#   0.84,
#   1.88,
#   3.47,
#   7.27,
#   12.63,
#   19.69,
#   31.63,
#   60.94,
#   98.02,
#   128.59,
#   158.61,
#   258.76,
#   274.77,
#   275.47,
#   339.38,
#   368.96,
#   378.36,
#   374.16,
#   349.92],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.12,
#   0.19,
#   0.44,
#   0.74,
#   1.98,
#   3.57,
#   6.6,
#   11.74,
#   17.28,
#   32.37,
#   61.86,
#   92.55,
#   170.5,
#   176.33,
#   275.01,
#   332.0,
#   378.96,
#   369.93,
#   435.93,
#   424.91,
#   398.14,
#   369.92],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.14,
#   0.29,
#   0.56,
#   1.14,
#   2.1,
#   3.74,
#   8.57,
#   13.95,
#   20.69,
#   32.71,
#   71.23,
#   124.74,
#   183.81,
#   196.29,
#   282.16,
#   335.2,
#   382.51,
#   439.1,
#   456.12,
#   421.3,
#   346.33,
#   350.57],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.13,
#   0.25,
#   0.5,
#   0.86,
#   2.16,
#   3.92,
#   7.02,
#   13.13,
#   19.39,
#   39.51,
#   59.97,
#   111.31,
#   185.09,
#   179.24,
#   291.96,
#   344.37,
#   388.81,
#   427.98,
#   368.65,
#   373.6,
#   429.5,
#   450.19],
#  [0.0,
#   0.01,
#   0.03,
#   0.07,
#   0.13,
#   0.24,
#   0.52,
#   0.95,
#   2.04,
#   4.0,
#   8.8,
#   15.23,
#   19.46,
#   40.52,
#   75.88,
#   111.86,
#   158.74,
#   194.7,
#   290.19,
#   324.5,
#   369.84,
#   375.13,
#   397.5,
#   449.3,
#   476.7,
#   433.76],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.13,
#   0.22,
#   0.47,
#   0.91,
#   1.82,
#   3.99,
#   7.97,
#   16.17,
#   16.9,
#   34.86,
#   58.14,
#   109.25,
#   166.33,
#   174.38,
#   240.25,
#   327.32,
#   317.11,
#   427.9,
#   370.78,
#   402.34,
#   378.13,
#   347.31],
#  [0.0,
#   0.02,
#   0.03,
#   0.07,
#   0.14,
#   0.28,
#   0.56,
#   1.09,
#   2.06,
#   3.89,
#   7.13,
#   14.21,
#   21.92,
#   32.41,
#   65.56,
#   107.06,
#   167.62,
#   193.84,
#   317.16,
#   385.85,
#   352.49,
#   391.7,
#   418.28,
#   393.61,
#   424.17,
#   449.97],
#  [0.0,
#   0.02,
#   0.03,
#   0.06,
#   0.12,
#   0.23,
#   0.55,
#   0.96,
#   2.04,
#   4.11,
#   8.32,
#   15.46,
#   18.16,
#   32.62,
#   63.57,
#   114.16,
#   173.62,
#   202.32,
#   281.71,
#   308.98,
#   378.22,
#   376.96,
#   403.35,
#   384.92,
#   416.88,
#   395.85],
#  [0.0,
#   0.01,
#   0.04,
#   0.06,
#   0.13,
#   0.28,
#   0.52,
#   0.7,
#   1.72,
#   2.9,
#   7.75,
#   13.05,
#   15.0,
#   32.24,
#   59.35,
#   95.57,
#   168.53,
#   167.11,
#   260.53,
#   294.4,
#   326.48,
#   344.35,
#   360.21,
#   368.07,
#   313.43,
#   369.38],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.11,
#   0.22,
#   0.35,
#   0.79,
#   1.71,
#   3.06,
#   7.35,
#   14.86,
#   18.78,
#   35.31,
#   62.77,
#   89.83,
#   136.73,
#   160.25,
#   259.88,
#   286.99,
#   363.9,
#   336.08,
#   330.85,
#   331.45,
#   345.91,
#   366.93],
#  [0.0,
#   0.01,
#   0.03,
#   0.05,
#   0.12,
#   0.22,
#   0.48,
#   1.01,
#   2.18,
#   3.87,
#   6.69,
#   13.09,
#   20.49,
#   37.42,
#   67.0,
#   116.84,
#   177.16,
#   179.74,
#   256.35,
#   280.74,
#   369.87,
#   434.33,
#   394.57,
#   384.56,
#   374.74,
#   411.32],
#  [0.0,
#   0.01,
#   0.03,
#   0.06,
#   0.09,
#   0.19,
#   0.54,
#   0.74,
#   1.98,
#   4.02,
#   7.31,
#   14.7,
#   18.74,
#   36.01,
#   51.57,
#   70.17,
#   153.63,
#   163.29,
#   230.89,
#   242.72,
#   292.47,
#   340.59,
#   331.03,
#   337.73,
#   344.33,
#   376.47]]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-49bef761b3dd> in <module>()
# ----> 1 print(latencies)
#
# NameError: name 'latencies' is not defined
